# %%
import pandas as pd
import numpy as np
from collections import defaultdict

import matplotlib.pyplot as plt
plt.style.use('ggplot')

import seaborn as sns
import re
# %matplotlib inline

# %%
amazon_skills = pd.read_csv('../data/amazon_jobs_dataset.csv')
amazon_skills.tail()
# Out:
#       Unnamed: 0                                              Title  \
# 3488        3488                                  Software Engineer
# 3489        3489                      Software Development Engineer
# 3490        3490   Software Development Engineer III - Mar. BR 2012
# 3491        3491  Software Development Engineer in Test II - IMM546
# 3492        3492              Software Development Engineer in Test
#
#                 location       Posting_date  \
# 3488  US, NV, Las Vegas     August 29, 2012
# 3489    US, WA, Seattle      April 23, 2012
# 3490    US, WA, Seattle      March  6, 2012
# 3491    US, WA, Seattle   November 28, 2011
# 3492    US, WA, Seattle       July  7, 2011
#
#                                             DESCRIPTION  \
# 3488  What are you currently doing? We’re building a...
# 3489  At Amazon Voice and Advanced Natural Shopping ...
# 3490  Employer: Amazon Corporate LLCPosition: Softwa...
# 3491  POSITIONS AVAILABLECompany: Amazon Corporate L...
# 3492  Kindle and Amazon are impacting the world with...
#
#                                    BASIC QUALIFICATIONS  \
# 3488  · 5+ years production Java software developmen...
# 3489  * Bachelor’s Degree in Computer Science or rel...
# 3490  Basic Qualifications:Education: Master’s degre...
# 3491                                                  -
# 3492  · Bachelor’s degree in Computer Science, Compu...
#
#                                PREFERRED QUALIFICATIONS
# 3488  · 7+ years Java software development in a prod...
# 3489  * Experience building complex software systems...
# 3490                                                  -
# 3491                                                  -
# 3492  · Experience with open source tools and resour...

# %%
#t1 = pd.DataFrame(amazon_skills['PREFERRED QUALIFICATIONS'])
#t2 = pd.DataFrame(amazon_skills['BASIC QUALIFICATIONS'])
#t = [t1,t2]
#result=pd.concat(t,axis=1)
#result.head()

# %%
title_count = amazon_skills.Title.value_counts()
title = amazon_skills['Title']
new = title_count[title_count>9]
print(new.count())

new.plot(kind='barh')
#new.plot(kind='barh')
#uni_title = pd.DataFrame(amazon_skills['Title'].unique())
# Out:
# 18

# %%
location_count = amazon_skills.location.value_counts()
loc_count=location_count[location_count>20]

print(loc_count.count())
loc_count.plot(kind='barh')
#print(location_count)
#tit
#plt.figure(figsize=(15,15))
# Out:
# 21

# %%
# Group by location counts of titles 
counts = amazon_skills.groupby(['location','Title']).size()
counts
# Out:
# location            Title
#                     Software Development Engineer                                                1
# AE, Dubai           Full Stack Developer                                                         1
# AU, NSW, Sydney     Amazon Aurora/MySQL - Systems Development Engineer                           1
#                     Lead DevOps/ Systems Development Engineer                                    1
#                     Prototyping Team Manager                                                     1
#                     Senior Software Development Engineer                                         1
#                     Senior Software Development Engineer - Network Control & Management          1
#                     Senior Software Engineer - Prototype                                         1
#                     Software Development Engineer                                                1
#                     Software Development Engineer- Sydney-Hiring Event                           1
#                     Software Development Manager                                                 1
#                     Systems Development Engineer - AWS RDS ( Relational Database Services)       1
# BR, SP, Sao Paulo   Amazon.com in Sao Paulo is Hiring Software Engineers III                     3
#                     Quality Assurance Engineer - Amazon Is Hiring For Sao Paulo, Brasil!         2
#                     Software Developer                                                           1
#                     Software Development Engineer                                                1
#                     Software Development Engineer Intern                                         1
#                     Software Development Intern                                                  1
#                     Software Development Intern - Amazon.com Sao Paulo office                    1
#                     Software Development Manager II - Amazon Is Hiring For Sao Paulo, Brasil!    1
# CA,                 Software Development Engineer - Tel Aviv Event (Mar 2017)                    1
#                     Software Development Engineer-Amazon.com                                     1
#                     ZURICH FAST - SDE 3 - Hiring Event                                           1
# CA, BC, Vancouver    Amazon Web Services (RDS) - Software Development Manager - Vancouver        1
#                      Software Development Engineer II                                            1
#                     Alexa Software Development Manager                                           1
#                     Applied Scientist, Alexa Smart Home                                          2
#                     Challenges with AWS Vancouver 2018- Stockholm, Sweden hiring event           1
#                     DE Pooling - Retail System International events                              1
#                     Manager, Software Development                                                1
#                                                                                                 ..
# US, WA, Seattle     Web Development Engineer - Amazon Connect                                    1
#                     Web Development Engineer - Elastic Beanstalk                                 3
#                     Web Development Engineer II                                                  3
#                     Web Development Engineer II - AMZ2363                                        1
#                     Web Development Engineer – AWS Systems Manager                               2
#                     Web Development Engineer – Advertiser Intelligence                           1
#                     Web Development Engineer – Internet of Things (IoT)                          1
#                     Web Development Engineer, AWS Elastic Load Balancing                         1
#                     Web Development Engineer, Container Services                                 1
#                     Web Development Engineer- AWS IoT Customer Experience Team                   1
#                     Website Development Engineer                                                 1
#                     Web Development Engineer                                                     1
#                     Windows and Mac/Xamarin Software Engineer - Amazon Drive                     1
#                     iOS Engineer                                                                 2
#                     iOS Software Development Engineer                                            1
# ZA, Cape Town       Front-End Engineer                                                           1
#                     Senior Software Development Engineer                                         1
#                     Senior Software Development Engineer - EC2 API Team                          1
#                     Senior Software Development Engineer - EC2 Placement Data Team               1
#                     Senior Software Development Engineer - EC2 Reserved Instances Team           1
#                     Senior Software Development Engineer, EC2 Cloud Manager Team                 2
#                     Software Development Engineer                                                1
#                     Software Development Engineer                                                1
#                     Software Development Engineer - Front-end -  EC2 Visual Platform Team        1
#                     Software Development Engineer – EC2 API Platform team                        1
#                     Software Development Engineer, Kumo Development Team                         2
#                     Software Development Manager                                                 1
#                     Software Development Manager, Kumo Development Team                          1
#                     Sr. Systems Engineer with database experience                                1
#                     UX Designer - EC2 UX Team                                                    1
# dtype: int64
